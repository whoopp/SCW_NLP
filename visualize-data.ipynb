# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
with open('SCW_comment_flairs_11_all', 'r') as f:
    lines = [abbreviate(name.strip()) for name in f.readlines()]

plt.hist(lines)
plt.show()
